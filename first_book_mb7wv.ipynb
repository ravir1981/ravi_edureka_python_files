# %%
print("hello world")

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
# ##### Heading 5
# ###### Heading 6
#
# Normal text
#
# - bullet 1
# - bullet 2
# - bullet 3
#
# print("hello world")
#
# ![image.png](data:image/png;base64,...)
